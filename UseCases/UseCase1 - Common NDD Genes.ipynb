# %% [markdown]
# ## Example 1: Neurodegeneration-Associated Genes in Humans
#
# We aggregated public data across AD, PD, ALS, and HD, identifying 139 overlapping genes. Using BioComet and the Leiden algorithm, we detected gene communities, leading to refined functional insights and highlighting potential inflammatory or metabolic pathways involved in neurodegeneration.
#
# This notebook aims to showcase BioComet's capability to navigate complex biological datasets, offering insights into disease mechanisms and potential therapeutic targets.

# %%
import biocomet as bc
from biocomet import examples

# load 139 common genes
common_genes = examples.hs_ndd_genes

common_genes
# Out:
# 0         COL4A1
# 1           CLK1
# 2           SMTN
# 3           PKD1
# 4      RAB11FIP4
#          ...
# 134         TNXB
# 135        RPL35
# 136         NT5E
# 137         USP4
# 138        MMRN2
# Length: 139, dtype: object

# %%
# build the PPI object with the default min score of 400 for a connection and the exclusion of solely text-based associations
PPI = bc.PPIGraph(gene_list=common_genes, organism='human', min_score=400)

# display the full PPI Graph
PPI.plot_PPI(full_network=True)
# Out:
# Saving interaction network to ./PPI_networks/full_network.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1281x1636>

# %% [markdown]
# #### Whole network analysis

# %%
# calculate the functional annotation
PPI.get_functional_annotation(full_network=True, categories='pathways')

# display the results with the network
PPI.plot_Wordclouds_PPI(full_network=True, categories='pathways')

# extract and display the results as a dataframe
full_network_results = PPI.func_annotation_full_network
full_network_results
# Out:
# Saving PPI word clouds to ./WordCloudPPI_networks/community Full Network's_ppi_wordcloud.png
# {'Full Network':          category          term  number_of_genes  \
#  0    COMPARTMENTS  GOCC:0005615               25
#  1    COMPARTMENTS  GOCC:0043226              102
#  2    COMPARTMENTS  GOCC:0043229               99
#  3    COMPARTMENTS  GOCC:0065010               16
#  4    COMPARTMENTS  GOCC:0070062               15
#  ..            ...           ...              ...
#  474           HPO    HP:0001895                4
#  475           HPO    HP:0002621                5
#  476           HPO    HP:0011024               23
#  477           HPO    HP:0011915                4
#  478           HPO    HP:0025031               33
#
#       number_of_genes_in_background  ncbiTaxonId  \
#  0                             1027         9606
#  1                            10113         9606
#  2                             9609         9606
#  3                              473         9606
#  4                              428         9606
#  ..                             ...          ...
#  474                             32         9606
#  475                             64         9606
#  476                           1384         9606
#  477                             32         9606
#  478                           2389         9606
#
#                                              inputGenes  \
#  0    [CD4, ITGB4, DNAJB1, NT5E, THBS1, PKD1, PDCD6,...
#  1    [CD4, ITGB4, GADD45B, NFKBIA, SLC17A7, STK38, ...
#  2    [CD4, ITGB4, GADD45B, NFKBIA, SLC17A7, STK38, ...
#  3    [ITGB4, DNAJB1, NT5E, THBS1, PKD1, PDCD6, CA4,...
#  4    [ITGB4, DNAJB1, NT5E, THBS1, PKD1, PDCD6, CA4,...
#  ..                                                 ...
#  474                        [RPL35, RPS15A, RPS19, HK1]
#  475                  [ANTXR1, FBN1, LMNA, ABCA1, TNXB]
#  476  [ITGB4, NFKBIA, SLC11A1, TBX3, RPL35, PDGFRB, ...
#  477                            [NT5E, FBN1, LMNA, B2M]
#  478  [ITGB4, NFKBIA, SLC11A1, TBX3, RPL35, ABCC9, P...
#
#                                          preferredNames       p_value      fdr  \
#  0    [CD4, ITGB4, DNAJB1, NT5E, THBS1, PKD1, PDCD6,...  7.190000e-08  0.00017
#  1    [CD4, ITGB4, GADD45B, NFKBIA, SLC17A7, STK38, ...  9.910000e-08  0.00017
#  2    [CD4, ITGB4, GADD45B, NFKBIA, SLC17A7, STK38, ...  7.270000e-08  0.00017
#  3    [ITGB4, DNAJB1, NT5E, THBS1, PKD1, PDCD6, CA4,...  3.400000e-07  0.00020
#  4    [ITGB4, DNAJB1, NT5E, THBS1, PKD1, PDCD6, CA4,...  5.270000e-07  0.00020
#  ..                                                 ...           ...      ...
#  474                        [RPL35, RPS15A, RPS19, HK1]  1.100000e-04  0.04980
#  475                  [ANTXR1, FBN1, LMNA, ABCA1, TNXB]  1.200000e-04  0.04980
#  476  [ITGB4, NFKBIA, SLC11A1, TBX3, RPL35, PDGFRB, ...  1.200000e-04  0.04980
#  477                            [NT5E, FBN1, LMNA, B2M]  1.100000e-04  0.04980
#  478  [ITGB4, NFKBIA, SLC11A1, TBX3, RPL35, ABCC9, P...  1.200000e-04  0.04980
#
#                                     description
#  0                          Extracellular space
#  1                                    Organelle
#  2                      Intracellular organelle
#  3     Extracellular membrane-bounded organelle
#  4                        Extracellular exosome
#  ..                                         ...
#  474                        Normochromic anemia
#  475                            Atherosclerosis
#  476  Abnormality of the gastrointestinal tract
#  477               Cardiovascular calcification
#  478        Abnormality of the digestive system
#
#  [479 rows x 10 columns]}

# %% [markdown]
# #### Community Detection and community analysis

# %%
# identify communities using the leiden algorithm
PPI.community_detection(algorithm='leiden', iterations=100)

# both, the leiden and louvain algorithm are non-deterministic. This means, that when run multiple times, so exact results might vary.
# therefore, we implemented the community detection in a way, so that it prints out the static seed for the best found partition in this trial
# so to reproduce the results, the algorithm can be run with this particular seed

# feel free to change the seed here, however, the following content is adapted to the seed 5944
PPI.community_detection(algorithm='leiden', seed=5944)

# calculate the functional annotation
PPI.get_functional_annotation(full_network=False, categories='pathways')

# display the results with the network
PPI.plot_Wordclouds_PPI(full_network=False, categories='pathways')

# extract and display the results as a dataframe
community_results = PPI.func_annotation

# in case you want to look at the functional enrichment tables:
# community_results
# Out:
# First few edge weights: [0.409, 0.416, 0.424, 0.424, 0.437]
# Mean weight: 0.6259150579150579
# Minimum weight: 0.4
# Maximum weight: 0.999
# The best modularity based on the networkx is 0.4811272938686066
# For reproducing exactly this community detection, run PPIGraph.community_detection(algorithm='leiden', seed=2525)
# First few edge weights: [0.409, 0.416, 0.424, 0.424, 0.437]
# Mean weight: 0.6259150579150579
# Minimum weight: 0.4
# Maximum weight: 0.999
# The modularity based on this seed is 0.4811272938686066
# Saving PPI word clouds to ./WordCloudPPI_networks/community 0's_ppi_wordcloud.png
# Saving PPI word clouds to ./WordCloudPPI_networks/community 1's_ppi_wordcloud.png
# Saving PPI word clouds to ./WordCloudPPI_networks/community 2's_ppi_wordcloud.png
# Saving PPI word clouds to ./WordCloudPPI_networks/community 3's_ppi_wordcloud.png
# Saving PPI word clouds to ./WordCloudPPI_networks/community 5's_ppi_wordcloud.png
# Saving PPI word clouds to ./WordCloudPPI_networks/community 6's_ppi_wordcloud.png
# {0:          category           term  number_of_genes  \
#  0    COMPARTMENTS   GOCC:0005886               13
#  1    COMPARTMENTS   GOCC:0009986                7
#  2    COMPARTMENTS   GOCC:0098802                6
#  3    COMPARTMENTS   GOCC:0005615                8
#  4    COMPARTMENTS   GOCC:0005925                5
#  ..            ...            ...              ...
#  243          PMID  PMID:26137471                5
#  244          PMID  PMID:35742923                5
#  245          PMID  PMID:36313397                5
#  246          PMID  PMID:31907034                5
#  247          PMID  PMID:34425902                6
#
#       number_of_genes_in_background  ncbiTaxonId  \
#  0                             3535         9606
#  1                              438         9606
#  2                              255         9606
#  3                             1027         9606
#  4                              269         9606
#  ..                             ...          ...
#  243                             25         9606
#  244                             26         9606
#  245                             26         9606
#  246                             26         9606
#  247                             75         9606
#
#                                              inputGenes  \
#  0    [CD4, NT5E, PDGFRB, ERBB2, CD34, SPTBN1, MSN, ...
#  1                [CD4, NT5E, CD34, MSN, ENG, MME, SPN]
#  2                    [CD4, ERBB2, TFR2, ADM, B2M, SPN]
#  3            [CD4, NT5E, MSN, ENG, MME, ADM, B2M, SPN]
#  4                         [PDGFRB, MSN, ENG, MME, B2M]
#  ..                                                 ...
#  243                     [NT5E, PDGFRB, CD34, ENG, SPN]
#  244                        [NT5E, CD34, ENG, MME, ADM]
#  245                        [CD4, NT5E, CD34, ENG, B2M]
#  246                     [CD4, NT5E, PDGFRB, CD34, ENG]
#  247                [CD4, NT5E, PDGFRB, CD34, ENG, MME]
#
#                                          preferredNames       p_value  \
#  0    [CD4, NT5E, PDGFRB, ERBB2, CD34, SPTBN1, MSN, ...  6.620000e-08
#  1                [CD4, NT5E, CD34, MSN, ENG, MME, SPN]  2.730000e-08
#  2                    [CD4, ERBB2, TFR2, ADM, B2M, SPN]  3.640000e-08
#  3            [CD4, NT5E, MSN, ENG, MME, ADM, B2M, SPN]  4.960000e-07
#  4                         [PDGFRB, MSN, ENG, MME, B2M]  1.930000e-06
#  ..                                                 ...           ...
#  243                     [NT5E, PDGFRB, CD34, ENG, SPN]  2.480000e-11
#  244                        [NT5E, CD34, ENG, MME, ADM]  2.960000e-11
#  245                        [CD4, NT5E, CD34, ENG, B2M]  2.960000e-11
#  246                     [CD4, NT5E, PDGFRB, CD34, ENG]  2.960000e-11
#  247                [CD4, NT5E, PDGFRB, CD34, ENG, MME]  3.090000e-11
#
#            fdr                                        description
#  0    0.000063                                    Plasma membrane
#  1    0.000063                                       Cell surface
#  2    0.000063         Plasma membrane signaling receptor complex
#  3    0.000230                                Extracellular space
#  4    0.000630                                     Focal adhesion
#  ..        ...                                                ...
#  243  0.000001     (2015) Stem Cells for Cutaneous Wound Healing.
#  244  0.000002  (2022) Therapeutic Strategy of Mesenchymal-Ste...
#  245  0.000002  (2022) CRISPRCas9 and AAV mediated insertion o...
#  246  0.000002  (2020) Endometrial stromal cells exhibit a dis...
#  247  0.000002  (2021) Endometrial stemprogenitor cells and th...
#
#  [248 rows x 10 columns],
#  1:               category         term  number_of_genes  \
#  0              Process   GO:0002221                4
#  1              Process   GO:0070498                3
#  2              Process   GO:0006950               11
#  3              TISSUES  BTO:0000753                9
#  4              TISSUES  BTO:0000782                4
#  ..                 ...          ...              ...
#  225  NetworkNeighborAL     CL:16584                5
#  226  NetworkNeighborAL     CL:16731                3
#  227  NetworkNeighborAL     CL:16644                2
#  228  NetworkNeighborAL     CL:16734                2
#  229  NetworkNeighborAL      CL:3345                2
#
#       number_of_genes_in_background  ncbiTaxonId  \
#  0                              101         9606
#  1                               20         9606
#  2                             3358         9606
#  3                             1600         9606
#  4                              279         9606
#  ..                             ...          ...
#  225                            105         9606
#  226                             25         9606
#  227                             13         9606
#  228                             12         9606
#  229                             12         9606
#
#                                              inputGenes  \
#  0                          [NFKBIA, RELA, TLR6, IRAK4]
#  1                                 [RELA, IL1R1, IRAK4]
#  2    [NFKBIA, DDIT4, TP53INP1, HMGB1, TSC22D3, PSIP...
#  3    [NFKBIA, TP53INP1, HMGB1, TSC22D3, AHNAK, PSIP...
#  4                       [TSC22D3, AHNAK, PSIP1, IL1R1]
#  ..                                                 ...
#  225                 [NFKBIA, HMGB1, RELA, TLR6, IRAK4]
#  226                               [HMGB1, TLR6, IRAK4]
#  227                                     [NFKBIA, RELA]
#  228                                      [HMGB1, TLR6]
#  229                                     [MBNL3, CEBPD]
#
#                                          preferredNames       p_value  \
#  0                          [NFKBIA, RELA, TLR6, IRAK4]  9.910000e-07
#  1                                 [RELA, IL1R1, IRAK4]  6.250000e-07
#  2    [NFKBIA, DDIT4, TP53INP1, HMGB1, TSC22D3, PSIP...  2.480000e-06
#  3    [NFKBIA, TP53INP1, HMGB1, TSC22D3, AHNAK, PSIP...  5.000000e-07
#  4                       [TSC22D3, AHNAK, PSIP1, IL1R1]  5.010000e-05
#  ..                                                 ...           ...
#  225                 [NFKBIA, HMGB1, RELA, TLR6, IRAK4]  1.420000e-08
#  226                               [HMGB1, TLR6, IRAK4]  1.150000e-06
#  227                                     [NFKBIA, RELA]  5.640000e-05
#  228                                      [HMGB1, TLR6]  4.890000e-05
#  229                                     [MBNL3, CEBPD]  4.890000e-05
#
#            fdr                                        description
#  0    0.009800     Pattern recognition receptor signaling pathway
#  1    0.009800           interleukin-1-mediated signaling pathway
#  2    0.013000                                 Response to stress
#  3    0.001200                                    Lymphoid tissue
#  4    0.037500                                       T-lymphocyte
#  ..        ...                                                ...
#  225  0.000065  Toll-like Receptor Cascades, and Novel intrace...
#  226  0.001300  MyD88-dependent toll-like receptor signaling p...
#  227  0.037300  Mixed, incl. NF-kappa-B/Dorsal, and D domain o...
#  228  0.037300  MYD88 distinct input-output pathway, and UNC93...
#  229  0.037300  Myotonic dystrophy type 1, and CELF-3/4/5/6, R...
#
#  [230 rows x 10 columns],
#  2:               category          term  number_of_genes  \
#  0         COMPARTMENTS  GOCC:0005856                8
#  1         COMPARTMENTS  GOCC:0015630                7
#  2         COMPARTMENTS  GOCC:0043232               10
#  3         COMPARTMENTS  GOCC:0099513                5
#  4         COMPARTMENTS  GOCC:0099080                6
#  ..                 ...           ...              ...
#  209  NetworkNeighborAL      CL:26388                3
#  210  NetworkNeighborAL       CL:1769                3
#  211  NetworkNeighborAL       CL:1777                2
#  212  NetworkNeighborAL      CL:26390                2
#  213  NetworkNeighborAL      CL:26215                2
#
#       number_of_genes_in_background  ncbiTaxonId  \
#  0                             1575         9606
#  1                              973         9606
#  2                             3309         9606
#  3                              382         9606
#  4                              844         9606
#  ..                             ...          ...
#  209                             12         9606
#  210                             31         9606
#  211                              5         9606
#  212                              6         9606
#  213                             33         9606
#
#                                              inputGenes  \
#  0    [TUBA4A, TUBB6, TUBB3, TUBB, LMNA, HSPA1A, NDE...
#  1    [TUBA4A, TUBB6, TUBB3, TUBB, HSPA1A, NDE1, KIF5C]
#  2    [TUBA4A, DNAJB1, TUBB6, TUBB3, TUBB, LMNA, HSP...
#  3                   [TUBA4A, TUBB6, TUBB3, TUBB, LMNA]
#  4             [TUBA4A, TUBB6, TUBB3, TUBB, LMNA, NDE1]
#  ..                                                 ...
#  209                              [TUBA4A, TUBB3, TUBB]
#  210                         [DNAJB1, HSP90AB1, HSPA1A]
#  211                                   [DNAJB1, HSPA1A]
#  212                                    [TUBA4A, TUBB3]
#  213                                      [NDE1, KIF5C]
#
#                                          preferredNames       p_value  \
#  0    [TUBA4A, TUBB6, TUBB3, TUBB, LMNA, HSPA1A, NDE...  1.520000e-06
#  1    [TUBA4A, TUBB6, TUBB3, TUBB, HSPA1A, NDE1, KIF5C]  9.690000e-07
#  2    [TUBA4A, DNAJB1, TUBB6, TUBB3, TUBB, LMNA, HSP...  3.150000e-06
#  3                   [TUBA4A, TUBB6, TUBB3, TUBB, LMNA]  3.210000e-06
#  4             [TUBA4A, TUBB6, TUBB3, TUBB, LMNA, NDE1]  8.350000e-06
#  ..                                                 ...           ...
#  209                              [TUBA4A, TUBB3, TUBB]  1.010000e-07
#  210                         [DNAJB1, HSP90AB1, HSPA1A]  1.330000e-06
#  211                                   [DNAJB1, HSPA1A]  8.420000e-06
#  212                                    [TUBA4A, TUBB3]  1.120000e-05
#  213                                      [NDE1, KIF5C]  2.400000e-04
#
#            fdr                                        description
#  0    0.002200                                       Cytoskeleton
#  1    0.002200                           Microtubule cytoskeleton
#  2    0.002400       Intracellular non-membrane-bounded organelle
#  3    0.002400                       Polymeric cytoskeletal fiber
#  4    0.003200                             Supramolecular complex
#  ..        ...                                                ...
#  209  0.000058               Tubulin/FtsZ-like, C-terminal domain
#  210  0.000610  Mixed, incl. Chaperone cofactor-dependent prot...
#  211  0.002700  Denatured protein binding, and DnaJ homolog su...
#  212  0.003200  Microtubule-dependent trafficking of connexons...
#  213  0.046900                                    Kinesin complex
#
#  [214 rows x 10 columns],
#  3:               category          term  number_of_genes  \
#  0         COMPARTMENTS  GOCC:0005788                6
#  1         COMPARTMENTS  GOCC:0062023                6
#  2         COMPARTMENTS  GOCC:0005581                4
#  3         COMPARTMENTS  GOCC:0030312                6
#  4         COMPARTMENTS  GOCC:0005576                8
#  ..                 ...           ...              ...
#  283  NetworkNeighborAL      CL:19458                7
#  284  NetworkNeighborAL      CL:19463                5
#  285  NetworkNeighborAL      CL:19465                4
#  286  NetworkNeighborAL      CL:19468                3
#  287  NetworkNeighborAL      CL:19469                2
#
#       number_of_genes_in_background  ncbiTaxonId  \
#  0                              172         9606
#  1                              198         9606
#  2                               36         9606
#  3                              259         9606
#  4                             2079         9606
#  ..                             ...          ...
#  283                            119         9606
#  284                             49         9606
#  285                             43         9606
#  286                             32         9606
#  287                             18         9606
#
#                                              inputGenes  \
#  0       [THBS1, P4HA1, FBN1, COL5A1, COL4A1, SERPINH1]
#  1         [THBS1, COL14A1, FBN1, COL5A1, COL4A1, TNXB]
#  2                  [COL14A1, COL5A1, COL4A1, SERPINH1]
#  3         [THBS1, COL14A1, FBN1, COL5A1, COL4A1, TNXB]
#  4    [ITGB4, THBS1, TMEFF2, COL14A1, FBN1, COL5A1, ...
#  ..                                                 ...
#  283  [ITGB4, THBS1, P4HA1, COL14A1, COL5A1, COL4A1,...
#  284         [P4HA1, COL14A1, COL5A1, COL4A1, SERPINH1]
#  285                [COL14A1, COL5A1, COL4A1, SERPINH1]
#  286                          [COL14A1, COL5A1, COL4A1]
#  287                                  [COL14A1, COL5A1]
#
#                                          preferredNames       p_value  \
#  0       [THBS1, P4HA1, FBN1, COL5A1, COL4A1, SERPINH1]  8.110000e-10
#  1         [THBS1, COL14A1, FBN1, COL5A1, COL4A1, TNXB]  1.840000e-09
#  2                  [COL14A1, COL5A1, COL4A1, SERPINH1]  1.030000e-08
#  3         [THBS1, COL14A1, FBN1, COL5A1, COL4A1, TNXB]  8.850000e-09
#  4    [ITGB4, THBS1, TMEFF2, COL14A1, FBN1, COL5A1, ...  1.230000e-05
#  ..                                                 ...           ...
#  283  [ITGB4, THBS1, P4HA1, COL14A1, COL5A1, COL4A1,...  6.120000e-13
#  284         [P4HA1, COL14A1, COL5A1, COL4A1, SERPINH1]  1.610000e-10
#  285                [COL14A1, COL5A1, COL4A1, SERPINH1]  2.000000e-08
#  286                          [COL14A1, COL5A1, COL4A1]  1.450000e-06
#  287                                  [COL14A1, COL5A1]  7.580000e-05
#
#                fdr                                        description
#  0    1.870000e-06                        Endoplasmic reticulum lumen
#  1    2.120000e-06           Collagen-containing extracellular matrix
#  2    6.790000e-06                                    Collagen trimer
#  3    6.790000e-06                   External encapsulating structure
#  4    4.700000e-03                               Extracellular region
#  ..            ...                                                ...
#  283  1.400000e-09  Collagen formation, and Protein complex involv...
#  284  2.460000e-07        Collagen biosynthesis and modifying enzymes
#  285  1.830000e-05                       Collagen chain trimerization
#  286  1.100000e-03                       Collagen chain trimerization
#  287  4.330000e-02  Banded collagen fibril, and FACIT collagen trimer
#
#  [288 rows x 10 columns],
#  5:         category          term  number_of_genes  \
#  0   COMPARTMENTS  GOCC:0005634                8
#  1        Process    GO:0090304                7
#  2        Process    GO:0010467                6
#  3        Process    GO:0010468                8
#  4        Process    GO:0010604                7
#  5        Process    GO:0010605                7
#  6        Process    GO:0016070                6
#  7        Process    GO:0031323                8
#  8        Process    GO:0031324                6
#  9        Process    GO:0031325                7
#  10       Process    GO:0043170                8
#  11       Process    GO:0051171                8
#  12       Process    GO:0051173                7
#  13       Process    GO:0060788                2
#  14       Process    GO:0080090                8
#  15       Process    GO:0051172                6
#  16     Component    GO:0043232                8
#  17      Function    GO:0003676                8
#  18       Keyword       KW-0539                8
#  19       Keyword       KW-0678                4
#  20          RCTM    HSA-450604                2
#  21          RCTM   HSA-4641265                2
#  22          RCTM    HSA-380994                2
#
#      number_of_genes_in_background  ncbiTaxonId  \
#  0                            4787         9606
#  1                            2203         9606
#  2                            2101         9606
#  3                            4899         9606
#  4                            3533         9606
#  5                            2760         9606
#  6                            1550         9606
#  7                            5681         9606
#  8                            2265         9606
#  9                            3114         9606
#  10                           5781         9606
#  11                           5734         9606
#  12                           3166         9606
#  13                             12         9606
#  14                           5899         9606
#  15                           2403         9606
#  16                           5191         9606
#  17                           4003         9606
#  18                           5278         9606
#  19                            611         9606
#  20                             17         9606
#  21                             12         9606
#  22                             27         9606
#
#                                             inputGenes  \
#  0   [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  1   [TBX3, PTBP1, TCOF1, RTF1, KHSRP, EXOSC6, TCF7L2]
#  2           [TBX3, PTBP1, TCOF1, RTF1, KHSRP, EXOSC6]
#  3   [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  4   [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]
#  5   [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]
#  6           [TBX3, PTBP1, TCOF1, RTF1, KHSRP, EXOSC6]
#  7   [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  8           [TBX3, PTBP1, HDAC1, RTF1, KHSRP, TCF7L2]
#  9   [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]
#  10  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  11  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  12  [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]
#  13                                      [TBX3, HDAC1]
#  14  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  15          [TBX3, PTBP1, HDAC1, RTF1, KHSRP, TCF7L2]
#  16  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  17  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  18  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...
#  19                       [TBX3, PTBP1, HDAC1, TCF7L2]
#  20                                    [KHSRP, EXOSC6]
#  21                                    [HDAC1, TCF7L2]
#  22                                    [KHSRP, EXOSC6]
#
#                                         preferredNames   p_value     fdr  \
#  0   [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000012  0.0281
#  1   [TBX3, PTBP1, TCOF1, RTF1, KHSRP, EXOSC6, TCF7L2]  0.000002  0.0250
#  2           [TBX3, PTBP1, TCOF1, RTF1, KHSRP, EXOSC6]  0.000034  0.0459
#  3   [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000015  0.0459
#  4   [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]  0.000041  0.0459
#  5   [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]  0.000008  0.0459
#  6           [TBX3, PTBP1, TCOF1, RTF1, KHSRP, EXOSC6]  0.000006  0.0459
#  7   [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000048  0.0459
#  8           [TBX3, PTBP1, HDAC1, RTF1, KHSRP, TCF7L2]  0.000053  0.0459
#  9   [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]  0.000017  0.0459
#  10  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000055  0.0459
#  11  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000052  0.0459
#  12  [TBX3, PTBP1, HDAC1, RTF1, KHSRP, EXOSC6, TCF7L2]  0.000019  0.0459
#  13                                      [TBX3, HDAC1]  0.000013  0.0459
#  14  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000065  0.0463
#  15          [TBX3, PTBP1, HDAC1, RTF1, KHSRP, TCF7L2]  0.000074  0.0493
#  16  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000023  0.0478
#  17  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000003  0.0144
#  18  [TBX3, PTBP1, HDAC1, TCOF1, RTF1, KHSRP, EXOSC...  0.000027  0.0179
#  19                       [TBX3, PTBP1, HDAC1, TCF7L2]  0.000060  0.0200
#  20                                    [KHSRP, EXOSC6]  0.000025  0.0299
#  21                                    [HDAC1, TCF7L2]  0.000013  0.0299
#  22                                    [KHSRP, EXOSC6]  0.000058  0.0443
#
#                                            description
#  0                                             Nucleus
#  1                      Nucleic acid metabolic process
#  2                                     Gene expression
#  3                       Regulation of gene expression
#  4   Positive regulation of macromolecule metabolic...
#  5   Negative regulation of macromolecule metabolic...
#  6                               RNA metabolic process
#  7            Regulation of cellular metabolic process
#  8   Negative regulation of cellular metabolic process
#  9   Positive regulation of cellular metabolic process
#  10                    Macromolecule metabolic process
#  11  Regulation of nitrogen compound metabolic process
#  12  Positive regulation of nitrogen compound metab...
#  13                       Ectodermal placode formation
#  14            Regulation of primary metabolic process
#  15  Negative regulation of nitrogen compound metab...
#  16       Intracellular non-membrane-bounded organelle
#  17                               Nucleic acid binding
#  18                                            Nucleus
#  19                                          Repressor
#  20           KSRP (KHSRP) binds and destabilizes mRNA
#  21                     Repression of WNT target genes
#  22  ATF4 activates genes in response to endoplasmi...  ,
#  6:               category          term  number_of_genes  \
#  0         COMPARTMENTS  GOCC:0022626                5
#  1         COMPARTMENTS  GOCC:1990904                7
#  2         COMPARTMENTS  GOCC:0044391                5
#  3         COMPARTMENTS  GOCC:0022625                3
#  4         COMPARTMENTS  GOCC:0043232                7
#  ..                 ...           ...              ...
#  134  NetworkNeighborAL        CL:156                6
#  135  NetworkNeighborAL        CL:165                5
#  136  NetworkNeighborAL        CL:166                3
#  137  NetworkNeighborAL        CL:271                2
#  138  NetworkNeighborAL        CL:168                2
#
#       number_of_genes_in_background  ncbiTaxonId  \
#  0                               89         9606
#  1                              564         9606
#  2                              155         9606
#  3                               38         9606
#  4                             3309         9606
#  ..                             ...          ...
#  134                             76         9606
#  135                             61         9606
#  136                             53         9606
#  137                              8         9606
#  138                             40         9606
#
#                                              inputGenes  \
#  0                [RPL35, RPS15A, RPL39, RPL10A, RPS19]
#  1    [RPL35, NPM1, TSR1, RPS15A, RPL39, RPL10A, RPS19]
#  2                [RPL35, RPS15A, RPL39, RPL10A, RPS19]
#  3                               [RPL35, RPL39, RPL10A]
#  4    [RPL35, NPM1, TSR1, RPS15A, RPL39, RPL10A, RPS19]
#  ..                                                 ...
#  134      [RPL35, RPS15A, RPL39, SERBP1, RPL10A, RPS19]
#  135              [RPL35, RPS15A, RPL39, RPL10A, RPS19]
#  136                             [RPL35, RPL10A, RPS19]
#  137                                    [RPS15A, RPL39]
#  138                                     [RPL35, RPS19]
#
#                                          preferredNames       p_value  \
#  0                [RPL35, RPS15A, RPL39, RPL10A, RPS19]  1.230000e-10
#  1    [RPL35, NPM1, TSR1, RPS15A, RPL39, RPL10A, RPS19]  1.290000e-10
#  2                [RPL35, RPS15A, RPL39, RPL10A, RPS19]  1.820000e-09
#  3                               [RPL35, RPL39, RPL10A]  4.650000e-07
#  4    [RPL35, NPM1, TSR1, RPS15A, RPL39, RPL10A, RPS19]  2.590000e-05
#  ..                                                 ...           ...
#  134      [RPL35, RPS15A, RPL39, SERBP1, RPL10A, RPS19]  1.200000e-13
#  135              [RPL35, RPS15A, RPL39, RPL10A, RPS19]  2.010000e-11
#  136                             [RPL35, RPL10A, RPS19]  1.200000e-06
#  137                                    [RPS15A, RPL39]  6.480000e-06
#  138                                     [RPL35, RPS19]  1.200000e-04
#
#                fdr                                        description
#  0    2.820000e-07                                 Cytosolic ribosome
#  1    2.820000e-07                          Ribonucleoprotein complex
#  2    1.400000e-06                                  Ribosomal subunit
#  3    2.100000e-04                  Cytosolic large ribosomal subunit
#  4    8.500000e-03       Intracellular non-membrane-bounded organelle
#  ..            ...                                                ...
#  134  5.480000e-10                             Viral mRNA Translation
#  135  6.550000e-09                     Cytoplasmic ribosomal proteins
#  136  3.200000e-04                     Cytoplasmic ribosomal proteins
#  137  1.600000e-03  Mixed, incl. Ribosomal protein L7Ae/L30e/S12e/...
#  138  2.970000e-02                     Cytoplasmic ribosomal proteins
#
#  [139 rows x 10 columns]}

# %%
# based on the results with seed 5944, we can label the community e.g. like that:

community_labels = {
    0: "Hematopoiesis & Cell Adhesion",              #Combines the themes of hematopoietic lineage development and cell adhesion processes.
    1: "Immune Response & Signaling",                #Captures the broad theme of immune response mechanisms, including TLR signaling and NF-kappa B pathways.
    2: "Cell Cycle & Mitotic Regulation",            #Reflects the focus on cell cycle processes, mitotic events, and related regulatory mechanisms.
    3: "Extracellular Matrix & Collagen Synthesis",  #Highlights the emphasis on extracellular matrix organization and collagen-related processes.
    5: "mRNA Stability & Stress Response",           #Represents the processes related to mRNA stability and cellular responses to stress, including WNT signaling repression.
    6: "rRNA Processing & Protein Targeting",        #Encompasses themes of ribosomal RNA processing and mechanisms of protein targeting, reflecting a focus on fundamental cellular processes.
}

# %% [markdown]
# Now we can inspect those genes contributing to the Disease pathway in of the Reactome database and see which communities those genes contribute to

# %%
# we can derive the table from the funcitional enrichment results on the whole graph 
full_network_results_df = full_network_results['Full Network']

# from here, we can check, which genes actually contributed to the most significant pathway found: the reactome pathway 'Disease'
disease_genes = full_network_results_df[(full_network_results_df['description'] == 'Disease') & (full_network_results_df['category'] == 'RCTM')]['preferredNames']
disease_genes
# Out:
# 387    [CD4, NFKBIA, TUBA4A, NT5E, RPL35, THBS1, ABCC...
# Name: preferredNames, dtype: object

# %% [markdown]
# As the Term 'Disease' is quite unspecific, let's try to trace, if we find those genes contributing to this term as being spread out in different communities that are more descriptive of their underlying functinoal association

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

G = PPI.network.copy()

# Initial layout - spring layout for individual community clustering
pos = nx.spring_layout(G, seed=42)

# Step 1: Identify and remove nodes from community -1
nodes_to_remove = [node for node in G.nodes if G.nodes[node]['community'] == -1]
G.remove_nodes_from(nodes_to_remove)

# Calculate the centroid for each community
community_centroids = {}
for community in set(nx.get_node_attributes(G, 'community').values()):
    nodes_in_community = [node for node in G.nodes if G.nodes[node]['community'] == community]
    if nodes_in_community:  # Check if the community is not empty
        x_coords = [pos[node][0] for node in nodes_in_community]
        y_coords = [pos[node][1] for node in nodes_in_community]
        centroid = (np.mean(x_coords), np.mean(y_coords))
        community_centroids[community] = centroid

# Adjust node positions to enhance community clustering
# Define the scale for inter-community and intra-community adjustment
inter_community_scale = 10
intra_community_scale = 0.15

adjusted_pos = {}
for node in G.nodes:
    community = G.nodes[node]['community']
    original_pos = pos[node]
    centroid = community_centroids.get(community, (0, 0))  # Fallback to (0,0) if not found
    # Calculate adjusted position
    adjusted_x = centroid[0] + intra_community_scale * (original_pos[0] - centroid[0])
    adjusted_y = centroid[1] + intra_community_scale * (original_pos[1] - centroid[1])
    adjusted_pos[node] = (adjusted_x * inter_community_scale, adjusted_y * inter_community_scale)


# Extract weights
weights = [G[u][v]['weight'] for u,v in G.edges()]
# Normalize weights (optional, depending on your data)
max_weight = max(weights)
min_weight = min(weights)
normalized_weights = [(weight - min_weight) / (max_weight - min_weight) for weight in weights]

# Calculate the figure center by averaging all adjusted node positions
all_x, all_y = zip(*adjusted_pos.values())
center_x, center_y = np.mean(all_x), np.mean(all_y)

# Visualization
plt.figure(figsize=(12, 8))
# Draw nodes, remembering the color coding for disease state
disease_colors = [G.nodes[n]['Disease'] for n in G.nodes]  # 0 or 1 indicating disease state
color_map = {0: 'blue', 1: 'red'}  # Mapping of disease state to color
nx.draw_networkx_nodes(G, adjusted_pos, node_color=[color_map[disease] for disease in disease_colors], node_size=50, alpha=0.8)

# Draw edges with width and alpha based on weight
for (u, v), lw, alpha in zip(G.edges(), normalized_weights, normalized_weights):
    nx.draw_networkx_edges(G, adjusted_pos, edgelist=[(u, v)], width=lw*3, alpha=alpha)  # Adjust multiplier and alpha offset as needed

# Adjusting label positions
for community, centroid in community_centroids.items():
    adjusted_centroid = (centroid[0] * inter_community_scale, centroid[1] * inter_community_scale)
    
    # Calculate the difference from the center
    diff_x = adjusted_centroid[0] - center_x
    diff_y = adjusted_centroid[1] - center_y
    
    # Calculate new label positions at 1.2 times the difference from the center
    label_x = center_x + 1.25 * diff_x
    label_y = center_y + 1.25 * diff_y
    
    plt.text(label_x, label_y, f'Community {community}:\n{community_labels[community]}', 
             horizontalalignment='center', verticalalignment='center', 
             fontsize=12, fontweight='bold',
             bbox=dict(facecolor='white', alpha=0.4, edgecolor='grey', boxstyle='round,pad=0.5'))

# Adding a legend for the disease state
red_patch = mpatches.Patch(color='red', label='Yes')
blue_patch = mpatches.Patch(color='blue', label='No')
plt.legend(handles=[red_patch, blue_patch], title="Member of Reactome\n"
                                                  " Pathway Disease", title_fontsize='13', loc='upper right', fontsize='12')

# Add a title to the plot
plt.suptitle("Network Visualization by Community and Reactome Pathway 'Disease' Membership", fontsize=16, fontweight='bold')


plt.axis('off')
plt.show()

# %% [markdown]
# What we can see here, is that all of our more detaileld communities, somehow contribute to the significance of the general term 'Disease' when analyzing the gene list as one large input. This actually represents a prime example of how results that are related to a variety of underlying processes, can to a large extent contribute to unspecific top-level terms. While e.g. the genes found in community 2 do mainly contribute to terms related to Cell Cycle and mitotic regulation, they also partially contribute to the significance of the term 'Disease'. As the is true also for the other communities we find here, this more unspecific term gains more significance the more diverse biological processes are actually part of the results. This is why our community detection helped here to put more emphasize on the individual results hidden within this complex list of genes!
